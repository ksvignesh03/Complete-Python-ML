# %% [markdown]
# Strings

# %%
str_1= 'welcome'
str_2= """hai,
hello"""

print(str_2)
# Out:
# hai,
# hello

# %%
str_3= "hello world"
for i in str_3:
  print(i)
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
str_3[0]
# Out:
# 'h'

# %%
str_3[2:5]
# Out:
# 'llo'

# %%
str_3[-1]
# Out:
# 'd'

# %%
str_3= "hello world"
for i in str_3:
 print(i)
 if(i=="e"):
   break
# Out:
# h
# e

# %%
str_3= "hello world"
for i in str_3:
  print(i)
  if(i=="l"):
     break
 #print(i)
# Out:
# h
# e
# l

# %%
str_4 = "how are you"
for i in str_4:
  if(i=="w"):
    break
  print(i)
# Out:
# h
# o

# %%
str_3 = "hello world"
len(str_3)
# Out:
# 11

# %%
str_3 ="hello world"
for i in str_3:
  if(i==" "):
    continue
  print(i)
# Out:
# h
# e
# l
# l
# o
# w
# o
# r
# l
# d

# %%
str_3 ="  hello world"
print(str_3.strip())    ##method removes any whitespace from the beginning or the end:
# Out:
# hello world

# %%
str_3 ="  Hello woRlD"
str_3.lower()
# Out:
# '  hello world'

# %%
str_3 ="  Hello woRlD"
str_3.upper()
# Out:
# '  HELLO WORLD'

# %%
str_3 ="hello world"
str_3.replace("hello","hai")
# Out:
# 'hai world'

# %%
str_3 ="hello l world"
str_3.split("l")
# Out:
# ['he', '', 'o ', ' wor', 'd']

# %%
str_3 ="hello,world"
str_3.split(",")
# Out:
# ['hello', 'world']

# %%
test_str = "hello world"
if "t" in test_str:
  print("Yes")
else:
  print("No")
# Out:
# No

# %%
test_str = "hello world"
"T" in test_str
# Out:
# False

# %%
test_str = "hello world"
"T" not in test_str
# Out:
# True

# %%
a = "hello"
b = "world"
c = a+b
print(c)
# Out:
# helloworld

# %%
a = list("hello")
b = list("world")
for i in b:
  a.append(i)
print(a)
# Out:
# ['h', 'e', 'l', 'l', 'o', 'w', 'o', 'r', 'l', 'd']

# %%
applicant= input("Enter the applicant's name: ")
interviewer = input("Enter the interviewer's name: ")
time = input("Enter the appointment time: ")
print(interviewer, "will interview", applicant, "at", time)
# Out:
# Enter the applicant's name: vignesh
# Enter the interviewer's name: joseph
# Enter the appointment time: 10.30
# joseph will interview vignesh at 10.30

# %%
a =input("enter your name:")
b =int(input("enter your age:"))
print("my name is",a,"I am",b,"years old")
# Out:
# enter your name:vignesh
# enter your age:26
# my name is vignesh I am 26 years old

# %%
age = 36
txt = "My name is John,and I am {}"
print(txt.format(age))
# Out:
# My name is John,and I am 36

# %%
age = 36  ##wrong way of doing
txt = "My name is John,and I am",age
txt
# Out:
# ('My name is John,and I am', 36)

# %%
quantity = 4
itemno = 225
price = 50
myorder = "I want {} pieces of item {} for {} dollars"
print(myorder.format(quantity,itemno,price))
# Out:
# I want 4 pieces of item 225 for 50 dollars

# %%
quantity = 5
itemno = 225
price = 50
myorder = "I want to pay {2} dollars for {0} pieces of item {1}"
print(myorder.format(quantity,itemno,price))
# Out:
# I want to pay 50 dollars for 5 pieces of item 225

# %%
sent = "\"Mango\" is the national fruit of india"
sent
# Out:
# '"Mango" is the national fruit of india'

# %%
sent_1 = "it\'s alright"
sent_1
# Out:
# "it's alright"

# %%
a= "Mango is the national fruit \\ of india"
print(a)
# Out:
# Mango is the national fruit \ of india

# %%
test_str = "hello \n world"
print(test_str)
# Out:
# hello
#  world

# %%
test_str = "hello \r world"
print(test_str)
# Out:
#  world

# %%
test_str = "hello\tworld"
print(test_str)
# Out:
# hello	world

# %%
test_str = "hello \bworld"
print(test_str)
# Out:
# world

# %%
test_str = "hello w\borld"
print(test_str)
# Out:
# orld

# %%
test_str = "hello wo\bld"
print(test_str)
# Out:
# ld

# %%
test_str = "hello world"
test_str.capitalize()
# Out:
# 'Hello world'

# %%
str_1= "hai"
x=str_1.center(10,"0")
print(x)
# Out:
# 000hai0000

# %%
str_1= "hai"
x=str_1.center(20,"w")
print(x)
# Out:
# wwwwwwwwhaiwwwwwwwww

# %%
len(x)
# Out:
# 20

# %%
str_2 ="hello world"
str_2.count("hello")
# Out:
# 1

# %%
str_2 ="hello world"
str_2.count("l")
# Out:
# 3

# %%
str_2 = "India is my country"
str_2.count("d",1,6)
# Out:
# 1

# %%
str_2 = "India is my country"
str_2.count("i",0,10)
# Out:
# 2

# %%
str_2 = "India is my country"
str_2.endswith("country")
# Out:
# True

# %%
str_2 = "India is my country"
str_2.endswith("count")
# Out:
# False

# %%
str_2 = "India is my country."
str_2.endswith(".")
# Out:
# True

# %%
str_2 = "India is my country."
str_2.endswith("m",5,10)
# Out:
# True

# %%
str_3 = "h\te\tl\tl\to"
print(str_3)
# Out:
# h	e	l	l	o

# %%
str_3 = "h\te\tl\tl\to"
print(str_3.expandtabs(20))
# Out:
# h                   e                   l                   l                   o

# %%
str_3 = "h\te\tl\tl\to"
print(str_3.expandtabs(2))
# Out:
# h e l l o

# %%
str_3 = "india is my country"
print(str_3.find("is"))
# Out:
# 6

# %%
str_3 = "india is my country"
print(str_3.find("i",0,8))
# Out:
# 0

# %%
str_3 = "india is my country"
print(str_3.index("a"))
# Out:
# 4

# %%
str_3 = "india is my country"
print(str_3.find("z"))
# Out:
# -1

# %%
str_3 = "india is my country"
print(str_3.index("z"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-1f2a640ee9b0> in <module>()
#       1 str_3 = "india is my country"
# ----> 2 print(str_3.index("z"))
#
# ValueError: substring not found

# %%
str_4 ="hai"
print(str_4.isalpha())
# Out:
# True

# %%
str_4 ="hai123"
print(str_4.isalpha())
# Out:
# False

# %%
str_3 ="12356"
print(str_3.isdigit())
# Out:
# True

# %%
str_3 ="12356hai"
print(str_3.isdigit())
# Out:
# False

# %%
str_3 ="12356hai"
print(str_3.isalnum())
# Out:
# True

# %%
str_3 ="12356hai$%"
print(str_3.isalnum())
# Out:
# False

# %%
str_3 ="hai "
print(str_3.isidentifier())
# Out:
# False

# %%
str_3 ="hai_"
print(str_3.isidentifier())
# Out:
# True

# %%
str_3="hello"
print(str_3.islower())
# Out:
# True

# %%
str_3="hello"
print(str_3.isupper())
# Out:
# False

# %%
str_3="abc"
print(str_3.isspace())
# Out:
# False

# %%
str_3="   "
print(str_3.isspace())
# Out:
# True

# %%
str_3 = "The Indian Express"
print(str_3.istitle())
# Out:
# True

# %%
str_3 = "the indian express"
print(str_3.istitle())
# Out:
# False

# %%
str_4 = "abc"
print("*".join(str_4))
# Out:
# a*b*c

# %%
dict ={"one":"apple","two":"ball"}
print("*".join(dict))
# Out:
# one*two

# %%
dict ={"one":"apple","two":"ball"}
print("#".join(dict))
# Out:
# one#two

# %%
str_5 ="hello"
print(str_5.zfill(10))
# Out:
# 00000hello

# %%
str_5 ="Hello world"
print(str_5.swapcase())
# Out:
# hELLO WORLD

# %%
str_5 ="india is my country"
str_5.startswith("india")
# Out:
# True

# %%
str_5 ="india is my country"
str_5.startswith("i",0,5)
# Out:
# True

# %%
str_6 = "  hello   "
str_6.strip()
# Out:
# 'hello'

# %%
str_6 = "  hello   "
str_6.rstrip()
# Out:
# '  hello'

# %%
str_6 = "  hello   "
str_6.lstrip()
# Out:
# 'hello   '

# %%
txt_1 = "i like banana"
a=(txt_1.replace("banana", "apple"))
print(a)
# Out:
# i like apple

# %%
txt_1 = "i like cricket"
b=(txt_1.replace("cricket", "football"))
print(b)
# Out:
# i like football

# %%
txt_2 = "i like like banana,like like apple"
x=(txt_2.replace("like","is",3))
print(x)
# Out:
# i is is banana,is like apple

# %%
txt = "Hello, And Welcome To My World!"

x = txt.casefold()

print(x)
# Out:
# hello, and welcome to my world!

# %% [markdown]
# **Dictionary**

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
for i in my_dict:
  print(i)
# Out:
# 1
# 2
# 3

# %%
my_dict[1]
# Out:
# 'apple'

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict[2]="orange"
my_dict
# Out:
# {1: 'apple', 2: 'orange', 3: 'grapes'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
for i in my_dict:
  print(my_dict[i])
# Out:
# apple
# mango
# grapes

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
for i in my_dict:
  print(i,my_dict[i])
# Out:
# 1 apple
# 2 mango
# 3 grapes

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
for x,y in my_dict.items():
  print(x,y)
# Out:
# 1 apple
# 2 mango
# 3 grapes

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
len(my_dict)
# Out:
# 3

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict["4"] = "pineapple"
my_dict
# Out:
# {1: 'apple', 2: 'mango', 3: 'grapes', '4': 'pineapple'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict.pop(1)
my_dict
# Out:
# {2: 'mango', 3: 'grapes'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict.pop()
my_dict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-afb0a331b852> in <module>()
#       1 my_dict={1:"apple",2:"mango",3:"grapes"}
# ----> 2 my_dict.pop()
#       3 my_dict
#
# TypeError: pop expected at least 1 arguments, got 0

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict.popitem()
my_dict
# Out:
# {1: 'apple', 2: 'mango'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
del my_dict[2]
my_dict
# Out:
# {1: 'apple', 3: 'grapes'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
del my_dict
my_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-99-b43f073c4cef> in <module>()
#       1 my_dict={1:"apple",2:"mango",3:"grapes"}
#       2 del my_dict
# ----> 3 my_dict
#
# NameError: name 'my_dict' is not defined

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
my_dict.clear()
my_dict
# Out:
# {}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
x=my_dict.copy()
x
# Out:
# {1: 'apple', 2: 'mango', 3: 'grapes'}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
x = dict(my_dict)
x
# Out:
# {1: 'apple', 2: 'mango', 3: 'grapes'}

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %%
child1 = {
  "name" : "Emil",
  "year" : 2004
}
child2 = {
  "name" : "Tobias",
  "year" : 2007
}
child3 = {
  "name" : "Linus",
  "year" : 2011
}

myfamily = {
  "child1" : child1,
  "child2" : child2,
  "child3" : child3
}
print(myfamily)
# Out:
# {'child1': {'name': 'Emil', 'year': 2004}, 'child2': {'name': 'Tobias', 'year': 2007}, 'child3': {'name': 'Linus', 'year': 2011}}

# %%
my_dict=dict({"one":"apple","two":"mango","three":"grapes"})
my_dict
# Out:
# {'one': 'apple', 'three': 'grapes', 'two': 'mango'}

# %%
my_dict=dict(one="apple",two="mango",three="grapes")
my_dict
# Out:
# {'one': 'apple', 'three': 'grapes', 'two': 'mango'}

# %%
my_dict=dict({"one":"apple","two":"mango","three":"grapes"})
my_dict
# Out:
# {'one': 'apple', 'three': 'grapes', 'two': 'mango'}

# %%
tuple_1 = ("x","y","z")
var = dict.fromkeys(tuple_1)
print(var)
# Out:
# {'x': None, 'y': None, 'z': None}

# %%
tuple_1 = ("x","y","z")
val = 5
var = dict.fromkeys(tuple_1,val)
print(var)
# Out:
# {'x': 5, 'y': 5, 'z': 5}

# %%
tuple_1 = ["x","y","z"]
val = 5
var = dict.fromkeys(tuple_1,val)
print(var)
# Out:
# {'x': 5, 'y': 5, 'z': 5}

# %%
tuple_1 = ["x","y","z"]
val = [1,2,3]
var = dict.fromkeys(tuple_1,val)
print(var)
# Out:
# {'x': [1, 2, 3], 'y': [1, 2, 3], 'z': [1, 2, 3]}

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
x=my_dict.get(2)
x
# Out:
# 'mango'

# %%
my_dict={1:"apple",2:"mango",3:"grapes"}
x=my_dict.items()
x
# Out:
# dict_items([(1, 'apple'), (2, 'mango'), (3, 'grapes')])

# %% [markdown]
# **Sets**

# %%
set = {"apple", "banana", "cherry"}

for x in set:
  print(x)
# Out:
# cherry
# banana
# apple

# %%
set = {"apple", "banana", "cherry"}
print("banana" in set)
# Out:
# True

# %%
set = {"apple", "banana", "cherry"}
print("banana" not in set)
# Out:
# False

# %%
set = {"apple", "banana", "cherry"}
set.add("mango")
set
# Out:
# {'apple', 'banana', 'cherry', 'mango'}

# %%
set = {"apple", "banana", "cherry"}
len(set)
print(len(set))
# Out:
# 3

# %%
set = {"apple", "banana", "cherry"}
set.add("mango","pineapple")
set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f68340d3f7d1> in <module>()
#       1 set = {"apple", "banana", "cherry"}
# ----> 2 set.add("mango","pineapple")
#       3 set
#
# TypeError: add() takes exactly one argument (2 given)

# %%
set = {"apple", "banana", "cherry"}
set.update(["mango","pineapple"])
set
# Out:
# {'apple', 'banana', 'cherry', 'mango', 'pineapple'}

# %%
set_1 = {"a", "b" , "c"}
set_2= {1, 2, 3}

set_3 = set_1.union(set_2)
print(set_3)
# Out:
# {'b', 1, 'c', 2, 3, 'a'}

# %%
set_1 = {"a", "b" , "c"}
set_2= {1, 2, 3}

set_3 = set_1.intersection(set_2)
print(set_3)
# Out:
# set()

# %%
set_1 = {"a", "b" , "c"}
set_2= {1, 2, 3}

set_3 = set_1 | set_2
print(set_3)
# Out:
# {'b', 1, 'c', 2, 3, 'a'}

# %%
set_1 = {"a", "b" , "c"}
set_2= {1, 2, 3}

set_3 = set_1 & set_2
print(set_3)
# Out:
# set()

# %%
set = {"apple", "banana", "cherry"}
set.remove("apple")
set
# Out:
# {'banana', 'cherry'}

# %%
set = {"apple", "banana", "cherry"}
set.discard("apple")
set
# Out:
# {'banana', 'cherry'}

# %%
set = {"apple", "banana", "cherry"}
set.pop()
set
# Out:
# {'apple', 'banana'}

# %%
set = {"apple", "banana", "cherry"}
set.clear()
set
# Out:
# set()

# %%
my_set = {"apple", "banana", "cherry"}
del my_set
print(my_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-96b4bd96a5da> in <module>()
#       1 my_set = {"apple", "banana", "cherry"}
#       2 del my_set
# ----> 3 print(my_set)
#
# NameError: name 'my_set' is not defined

# %%
my_set_1 = {1,2,3}
my_set_2 = {"a","b","c"}
my_set_1.update(my_set_2)
print(my_set_1)
# Out:
# {'b', 1, 2, 3, 'c', 'a'}

# %%
set = {"apple", "banana", "cherry"}
set.copy()
set
# Out:
# {'apple', 'banana', 'cherry'}

# %%
set1 = {1, 2, 3, 4}  
set2 = set1.copy() 
print(set2)
# Out:
# {1, 2, 3, 4}

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","apple"}

set_3 = set_1.difference(set_2)
print(set_3)
# Out:
# {'cherry', 'banana'}

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","apple"}

set_3 = set_2.difference(set_1)
print(set_3)
# Out:
# {'microsoft', 'google'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

x.difference_update(y)

print(x)
# Out:
# {'cherry', 'banana'}

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

y.difference_update(x)

print(y)
# Out:
# {'microsoft', 'google'}

# %%
set_1 = {"a", "b" , "c"}
set_2 = {1, 2, 3}
set_3 = {"d","e","f"}

set_4 = set_1.union(set_2,set_3)
print(set_4)
# Out:
# {'b', 1, 'c', 2, 3, 'd', 'a', 'e', 'f'}

# %%
set_1 = {"a", "b" , "c"}
set_2 = {1, 2, 3}
set_3 = {"d","e","f"}

set_4 = set_1.intersection(set_2,set_3)
print(set_4)
# Out:
# set()

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","apple"}

set_3 = set_1.intersection(set_2)
set_3
# Out:
# {'apple'}

# %%
set_1 = {"a", "b" , "c"}
set_2 = {1, 2, 3,"a"}
set_3 = {"a","e","f"}

set_4 = set_1.intersection(set_2,set_3)
print(set_4)
# Out:
# {'a'}

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","dell"}

set_3 = set_1.isdisjoint(set_2)

print(set_3)
# Out:
# True

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","apple","banana","cherry"}

set_3 = set_1.issubset(set_2)

print(set_3)
# Out:
# True

# %%
set_1 = {"apple", "banana", "cherry","google","microsoft"}
set_2 ={"google","microsoft","apple"}

set_3 = set_1.issuperset(set_2)

print(set_3)
# Out:
# True

# %%
numbers=[100,200,300,400]
numbers.reverse()
numbers
# Out:
# [400, 300, 200, 100]

# %%
numbers=[100,200,300,400]
new_list=[4:-1]
new_list
# Out:
#   File "<ipython-input-83-7b389f82bdc3>", line 2
#     new_list=[4:-1]
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Exercises

# %%
list1 = ["M","na","i","Ke"]
list2 = ["y","me","s","lly"]

for(i,j) in zip(list1,list2):
  print(i,j)
# Out:
# M y
# na me
# i s
# Ke lly

# %%
list1 = ["M","na","i","Ke"]
list2 = ["y","me","s","lly"]

list3 = [i+j for i,j in zip(list1,list2)]
print(list3)
# Out:
# ['My', 'name', 'is', 'Kelly']

# %%
list_1 = [1,2,3,4,5,6,7]

list_2 = [i**2 for i in list_1]
print(list_2)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
list1 = ["Hello", "take"]
list2 = ["Dear", "sir"]

list3 = [x+y for x in list1 for y in list2]
print(list3)
# Out:
# ['HelloDear', 'Hellosir', 'takeDear', 'takesir']

# %%
list1 = ["Hello", "take"]  ## Not Correct
list2 = ["Dear", "sir"]
for x in list1:
  for y in list2:

    print(list(x+y))
# Out:
# ['H', 'e', 'l', 'l', 'o', 'D', 'e', 'a', 'r']
# ['H', 'e', 'l', 'l', 'o', 's', 'i', 'r']
# ['t', 'a', 'k', 'e', 'D', 'e', 'a', 'r']
# ['t', 'a', 'k', 'e', 's', 'i', 'r']

# %%
list1 = [10, 20, 30, 40]
list2 = [100, 200, 300, 400]

for x, y in zip(list1, list2[::-1]):
    print(x, y)
# Out:
# 10 400
# 20 300
# 30 200
# 40 100

# %%
li = [1,2,[0,9,8],6]
li[2][1]
# Out:
# 9

# %%
list1 = [10,20,[300,400,[5000,6000],500],30,40]
list1[2][2].append(7000)
list1
# Out:
# [10, 20, [300, 400, [5000, 6000, 7000], 500], 30, 40]

# %%
list_1 = ["a","b",["c",["d","e",["f","g"],"k"],"l"],"m","n"]
sublist= ["h","i","j"]
list_1[2][1][2].append(sublist)
list_1
# Out:
# ['a', 'b', ['c', ['d', 'e', ['f', 'g', ['h', 'i', 'j']], 'k'], 'l'], 'm', 'n']

# %%
list1 = [5,10,15,20,25,50,20]
list1[3]=200
list1
# Out:
# [5, 10, 15, 200, 25, 50, 20]

# %%
keys = ['Ten','Twenty','Thirty']
values = [10,20,30]

my_dictionary = dict(zip(keys,values))
my_dictionary
# Out:
# {'Ten': 10, 'Thirty': 30, 'Twenty': 20}

# %%
dict1 = {'ten':10,'Twenty':20,'Thirty':30}
dict2 = {'Thirty':30,'forty':40,'fifty':50}

dict1.update(dict2)
print(dict1)
# Out:
# {'ten': 10, 'Twenty': 20, 'Thirty': 30, 'forty': 40, 'fifty': 50}

# %%
SampleDict = {
    "class":{
        "student":{
            "name":"mike",
            "marks":{
                "physics":70,
                "history":80
            }
        }
    }
}

print(SampleDict["class"]["student"]["marks"]["history"])
# Out:
# 80

# %%
SampleDict = {
    "class":{
        "student":{
            "name":"mike",
            "marks":{
                "physics":70,
                "history":80
            }
        }
    }
}

print(SampleDict["class"]["student"]["name"])
# Out:
# mike

# %%
SampleDict = {
    "class":{
        "student":{
            "name":"mike",
            "marks":{
                "physics":70,
                "history":80
            }
        }
    }
}

print(SampleDict["marks"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-44a174ab979e> in <module>()
#      11 }
#      12
# ---> 13 print(SampleDict["marks"])
#
# KeyError: 'marks'

# %%
employees = ["Kelly","Emma","john"]
defaults = {"designation":"Application Developer","salary":8000}

x = dict.fromkeys(employees,defaults)
print(x)
# Out:
# {'Kelly': {'designation': 'Application Developer', 'salary': 8000}, 'Emma': {'designation': 'Application Developer', 'salary': 8000}, 'john': {'designation': 'Application Developer', 'salary': 8000}}

# %%
sampledict = {"name": "kelly",
              "age":25,
              "salary":8000,
              "city":"Newyork"}

keys = ["name","salary"]

dictionary = {k: sampledict[k] for k in keys}
print(dictionary)
# Out:
# {'name': 'kelly', 'salary': 8000}

# %%
sampleDict = {'a': 100, 'b': 200, 'c': 300}
print(200 in sampleDict.values())
# Out:
# True

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}

sampleDict['location'] = sampleDict['city']
del sampleDict["city"]
print(sampleDict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %%
sampleDict = {
  "name": "Kelly",
  "age":25,
  "salary": 8000,
  "city": "New york"
}

sampleDict['location'] = sampleDict.pop('city')
print(sampleDict)
# Out:
# {'name': 'Kelly', 'age': 25, 'salary': 8000, 'location': 'New york'}

# %%
sampleDict = {
  'Physics': 82,
  'Math': 65,
  'history': 75
}
print(min(sampleDict))
# Out:
# Math

# %%
sampleDict = {
     'emp1': {'name': 'Jhon', 'salary': 7500},
     'emp2': {'name': 'Emma', 'salary': 8000},
     'emp3': {'name': 'Brad', 'salary': 6000}
}

sampleDict["emp3"]["salary"]=8500
print(sampleDict)
# Out:
# {'emp1': {'name': 'Jhon', 'salary': 7500}, 'emp2': {'name': 'Emma', 'salary': 8000}, 'emp3': {'name': 'Brad', 'salary': 8500}}

# %%
keys = ['a', 'b', 'c', 'd', 'e']
values = [1, 2, 3, 4, 5]

dict(zip(keys,values))
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}

# %%
d = {}
for i in range(1,11):
    d[i]=i**2
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
d = {i:i**2 for i in range(1,11)}
d
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
original_dict = {'jack': 38, 'michael': 48,'guido': 57,'john': 33}

even_dict = {k: v for (k, v) in original_dict.items() if v % 2 == 0} 
print(even_dict)
# Out:
# {'jack': 38, 'michael': 48}

# %%
original_dict = {'jack': 38, 'michael': 48,'guido': 57,'john': 33}

young_dict = {k: v for (k, v) in original_dict.items() if v >= 40} 
print(young_dict)
# Out:
# {'michael': 48, 'guido': 57}

# %%
original_dict = {'jack': 38, 'michael': 48, 'guido': 57, 'john': 33}

new_dict_1 = {k: ('old' if v > 40 else 'young') for (k, v) in original_dict.items()}
print(new_dict_1)
# Out:
# {'jack': 'young', 'michael': 'old', 'guido': 'old', 'john': 'young'}

# %%
d = {i:{j:i*j for j in range (1,6)}for i in range(2,5)}
d
# Out:
# {2: {1: 2, 2: 4, 3: 6, 4: 8, 5: 10},
#  3: {1: 3, 2: 6, 3: 9, 4: 12, 5: 15},
#  4: {1: 4, 2: 8, 3: 12, 4: 16, 5: 20}}

# %%
dict = {i:{j:i*j for j in range (1,6)}for i in range(11,16)}
dict
# Out:
# {11: {1: 11, 2: 22, 3: 33, 4: 44, 5: 55},
#  12: {1: 12, 2: 24, 3: 36, 4: 48, 5: 60},
#  13: {1: 13, 2: 26, 3: 39, 4: 52, 5: 65},
#  14: {1: 14, 2: 28, 3: 42, 4: 56, 5: 70},
#  15: {1: 15, 2: 30, 3: 45, 4: 60, 5: 75}}

# %%
sampleset ={"yellow","orange","Black"}
samplelist = ["Blue","Green","Red"]
sampleset.update(samplelist)
sampleset
# Out:
# {'Black', 'Blue', 'Green', 'Red', 'orange', 'yellow'}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}

print(set1.intersection(set2))
# Out:
# {40, 50, 30}

# %%
set1 = {10, 20, 30}
set2 = {20, 40, 50}

set1.difference_update(set2)
print(set1)
# Out:
# {10, 30}

# %%
set_1 = {"apple", "banana", "cherry"}
set_2 ={"google","microsoft","apple"}

set_3 = set_1.isdisjoint(set_2)

print(set_3,set_1.intersection(set_2))
# Out:
# False {'apple'}

# %%
my_tuple = (1,2,3.78, 9.56)
my_tuple=my_tuple[::-1]
my_tuple
# Out:
# (9.56, 3.78, 2, 1)

# %%
tuple = ("orange",[10,20,30],(5,15,25))
tuple[1][1]
# Out:
# 20

# %%
tuple = ("a")
print(type(tuple))
# Out:
# <class 'str'>

# %%
tuple = ("a",)   # to fin the type of a single element in tuple we put "," after that element
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
tuple_1 =(10,20,30,40)

var_a = tuple[0]
var_b = tuple[1]
var_c = tuple[2]
var_d = tuple[3]

print(var_c)
# Out:
# 30

# %%
tuple_1 = (10,20,30,40)
a,b,c,d = tuple_1

print(a)
# Out:
# 10

# %%
a = (1,2,3)
b = (4,5,6)

a,b =b,a

print(a)
# Out:
# (4, 5, 6)

# %%
tuple1 = (11,[22,33],44,55)
tuple1[1][0] = 222
tuple1
# Out:
# (11, [222, 33], 44, 55)

# %%
tuple1 = (50,10,60,70,50)
tuple1.count(50)
# Out:
# 2

# %%
str1 = "PyNaTive"
lower = []
upper = []
for char in str1:
    if char.islower():
        lower.append(char)
    else:
        upper.append(char)
sort_str1 = ''.join(lower + upper)
print(sort_str1)
# Out:
# yaivePNT

# %%
str1 = "google.com"
dict = {}
for n in str1:
  keys = dict.keys()
  if n in keys:
    dict[n] += 1
  else:
    dict[n] = 1
print(dict)
# Out:
# {'g': 2, 'o': 3, 'l': 1, 'e': 1, '.': 1, 'c': 1, 'm': 1}

# %%
pip install sklearn

# %%
pip install pandas

# %%
pip install numpy
